# %%
square = lambda x: x * x

# %%
square(5)
# Out:
# 25

# %%
nums = [1, 2, 3, 4]

result = []

for i in nums:
    result.append(i * i)

print(result)
# Out:
# [1, 4, 9, 16]

# %%
nums = [1, 2, 3, 4]

result = list(map(lambda x: x * x, nums))

print(result)
# Out:
# [1, 4, 9, 16]

# %%
num = [1,2,3,4,5]

result = list(map(lambda x: x * x, num))

print(result)
# Out:
# [1, 4, 9, 16, 25]
